# %%
def sum_all(start=0,end=100,step=1):
    output=0
    for i in range(start,end+1,step):
        output += i
    return output
print("A.",sum_all(0,100,10))
print("B.",sum_all(end=100))
print("c.",sum_all(end=100,step=2))
# Out:
# A. 550
# B. 5050
# c. 2550

# %%
def mul(*values):
    output=1
    for i in range(len(values)):  #i = 1,2,3,4
        output *= values[i]
    return output
print(mul(5,7,9,10))
# Out:
# 3150

# %%
def mul(*values):
    s=1
    for i in values:
        s *= i
    return s
print(mul(10,50,20,10))
# Out:
# 100000

# %%
def factorial(n):
    output=1
    for i in range(1,n+1):
        output *= i
    return output
print("1!:",factorial(1))
print("2!:",factorial(2))
print("3!:",factorial(3))
print("4!:",factorial(4))
print("5!:",factorial(5))
print("12!:",factorial(12))
# Out:
# 1!: 1
# 2!: 2
# 3!: 6
# 4!: 24
# 5!: 120
# 12!: 479001600

# %%
def factorial(n):
    if n ==0:
        return 1
    else:
        return n*factorial(n-1)
print("1!:",factorial(1))
print("2!:",factorial(2))
print("3!:",factorial(3))
print("4!:",factorial(4))
print("5!:",factorial(5))
print("12!:",factorial(12))
# Out:
# 1!: 1
# 2!: 2
# 3!: 6
# 4!: 24
# 5!: 120
# 12!: 479001600

# %%
counter = 0
def fibonacci(n):
    global counter
    counter += 1
    if n == 1 or n==2 :
        return 1
    else: 
        return fibonacci(n-1)+fibonacci(n-2)

print("fibonacci(40):",fibonacci(40))
print("함수 호출 횟수 :",counter)
# Out:
# fibonacci(40): 102334155
# 함수 호출 횟수 : 204668309

# %%
dictionary = {1: 1,2: 1}          #dictionary 공간에 fibonacci(1)=1,fibonacci(2)=1 의 값
counter = 0
def fibonacci(n):
    global counter
    counter += 1
    if n in dictionary :
        return dictionary[n]
    else:
        output = fibonacci(n-1)+fibonacci(n-2)   
        dictionary[n] = output                   #dictionary에 구한값을 저장
        return output

print("fibonacci(40):",fibonacci(40))
print("함수 호출 횟수 :",counter)
print("fibonacci(80):",fibonacci(80))
print("함수 호출 횟수 :",counter)
# Out:
# fibonacci(40): 102334155
# 함수 호출 횟수 : 77
# fibonacci(80): 23416728348467685
# 함수 호출 횟수 : 158

# %%
import random

hangules = list ("가나다라마바사아자차카타파하")
with open("info.txt","w", encoding="utf8")as file:
    for i in range(1000):
        name= random.choice(hangules)+random.choice(hangules)
        weight = random.randrange(40,100)
        height = random.randrange(140,200)
        file.write("{},{},{}\n".format(name,weight,height))

# %%
with open("info.txt","r",encoding="utf8")as file:
    for line in file:
        (name,weight,height)=line.strip().split(",") #strip 앞뒤 공백제거 (많이쓰임)
        if (not name) or (not weight) or (not height):
            continue
        bmi= int(weight)/((int(height)/100)**2)
        result=" "
        if 25 <= bmi:
            result="과체중"
        elif 18.5 <= bmi:
            result="정상체중"
        else:
            result="저체중"
        print("\n".join([
            "이름:{}",
            "몸무게:{}",
            "키:{}",
            "BMI:{}",
            "결과:{}"
        ]).format(name,weight,height,bmi,result))
        print()
# Out:
# 이름:차아
# 몸무게:44
# 키:196
# BMI:11.453561016243233
# 결과:저체중
#
# 이름:자마
# 몸무게:71
# 키:198
# BMI:18.110396898275688
# 결과:저체중
#
# 이름:나차
# 몸무게:51
# 키:156
# BMI:20.956607495069033
# 결과:정상체중
#
# 이름:바차
# 몸무게:79
# 키:152
# BMI:34.193213296398895
# 결과:과체중
#
# 이름:타가
# 몸무게:93
# 키:174
# BMI:30.71739992072929
# 결과:과체중
#
# 이름:나나
# 몸무게:57
# 키:179
# BMI:17.789706937985706
# 결과:저체중
#
# 이름:나타
# 몸무게:56
# 키:177
# BMI:17.87481247406556
# 결과:저체중
#
# 이름:가하
# 몸무게:84
# 키:173
# BMI:28.06642386982525
# 결과:과체중
#
# 이름:다바
# 몸무게:50
# 키:146
# BMI:23.45655845374367
# 결과:정상체중
#
# 이름:라차
# 몸무게:92
# 키:196
# BMI:23.94835485214494
# 결과:정상체중
#
# 이름:라아
# 몸무게:71
# 키:143
# BMI:34.72052423101375
# 결과:과체중
#
# 이름:마나
# 몸무게:60
# 키:156
# BMI:24.654832347140037
# 결과:정상체중
#
# 이름:하카
# 몸무게:79
# 키:180
# BMI:24.382716049382715
# 결과:정상체중
#
# 이름:카가
# 몸무게:50
# 키:163
# BMI:18.818924310286427
# 결과:정상체중
#
# 이름:마라
# 몸무게:87
# 키:170
# BMI:30.103806228373706
# 결과:과체중
#
# 이름:다라
# 몸무게:87
# 키:145
# BMI:41.37931034482759
# 결과:과체중
#
# 이름:자아
# 몸무게:42
# 키:180
# ...

# %%
from urllib import request
target= request.urlopen("https://naver.com")
output=target.read()
print(output)
# Out:
# b'   <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="\xeb\x84\xa4\xec\x
# ...

# %%
# !pip install beautifulsoup4

# %%
# !pip install Flask
